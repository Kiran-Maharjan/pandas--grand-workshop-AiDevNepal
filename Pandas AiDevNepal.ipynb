# %% [markdown]
# ------------- Pandas (python library)-----------------------------

# %% [markdown]
# Pandas is a Python package providing fast, flexible, and expressive data structures designed to make working with “relational” or “labeled” data both easy and intuitive.
#
# It aims to be the fundamental high-level building block for doing practical, real world data analysis in Python.

# %% [markdown]
# ###Pandas(30 mins)
#       1.  Csv reading
#       2.  Data Frame
#       3.  Loc/iloc
#       4.  Drop
#       5.  Fillna
#       6.  Describe
#       7.  Info
#       8.  Mean, median, sum
#       9.  Mapping
#       10. Plot
#       11. Visualization

# %% [markdown]
# Install pandas::::: https://pandas.pydata.org/pandas-docs/stable/install.html

# %% [markdown]
#                 !!!!   Errors  !!!
# --Possible ways you can make errors working with pandas
#         .. May be the file save in Excel in not in .csv format
#         .. May be the file path is not correct
#         .. pandas library is not imported
#         .. using conda environment and it cannot find library
#
#
# --or can try adding these code
# #import sys
# #sys.executable
#
# #from IPython.display import display

# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ---1.  Csv reading

# %%
df = pd.read_csv('train.csv')

#--to print all items available 
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#  .head()   prints limited fist items
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
#---print from last item
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
#  2.  Data Frame

# %% [markdown]
# Dataframe is a main object in Pandas. It is used to represent data with rows and columns (tabular or excel spreadsheet like data)

# %%
weather_data={
    'day':['1/1/2018','1/2/2018','1/3/2018'],
    'temperature':[32,35,28],
    'windspeed':[6,7,2],
}

df1=pd.DataFrame(weather_data);
df1
# Out:
#         day  temperature  windspeed
# 0  1/1/2018           32          6
# 1  1/2/2018           35          7
# 2  1/3/2018           28          2

# %%
#what is it's shape
df.shape
#---assign rows and column
#rows,columns=df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#----get specific columns
df1 = df[['PassengerId','Survived']]
df1.head()
# Out:
#    PassengerId  Survived
# 0            1         0
# 1            2         1
# 2            3         1
# 3            4         1
# 4            5         0

# %%
#when you define  'Survived' with out []
df1 = df['Survived']
df1.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
#---get range of value
df[2:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
#
#              Ticket    Fare Cabin Embarked
# 2  STON/O2. 3101282   7.925   NaN        S
# 3            113803  53.100  C123        S
# 4            373450   8.050   NaN        S

# %% [markdown]
#  3.  Loc/iloc
#      ---locate the particular data

# %%
#--use index value
df.loc[3]
# Out:
# PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Age                                                      35
# SibSp                                                     1
# Parch                                                     0
# Ticket                                               113803
# Fare                                                   53.1
# Cabin                                                  C123
# Embarked                                                  S
# Name: 3, dtype: object

# %%
#--- iloc picks perticular data of the selected rows, here prints value female of 3rd row
#----first item is 0,1,2
#---try changing value of [_,#]
df.iloc[3,4]
# Out:
# 'female'

# %% [markdown]
#  4.  Drop

# %%
df.drop(columns=['Parch'])
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %% [markdown]
#  5.  Fillna
#       ---It fills the NA (not Available) value with some other values

# %%
#df.fillna(0)
#----Here as 'Age' cannot be 0, it is assigned as mean and float value is converted to integer
#---'Cabin' cannot be int or float,, it is assigned 'no event'

df=df.fillna({
    'Age':df['Age'].mean().astype(int),
        'Cabin':'no event'
})
#df.fillna(dict)

#df.head()

df.loc[17]
# Out:
# PassengerId                              18
# Survived                                  1
# Pclass                                    2
# Name           Williams, Mr. Charles Eugene
# Sex                                    male
# Age                                      29
# SibSp                                     0
# Parch                                     0
# Ticket                               244373
# Fare                                     13
# Cabin                              no event
# Embarked                                  S
# Name: 17, dtype: object

# %% [markdown]
# 6.  Describe

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.560236    0.523008
# std     257.353842    0.486592    0.836071   13.005010    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
#  7.  Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          891 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
#  8.  Mean, median, sum

# %%
#df['Survived'].mean()
#df['Survived'].median()
df['Survived'].sum()
# Out:
# 342

# %% [markdown]
#  9.  Mapping
#       --it mapp data of one set to another..
#       --here x is defined with one data and so y
#       -- then x index maps to y values

# %%
x = pd.Series([1,2,3], index=['one', 'two', 'three'])
x
# Out:
# one      1
# two      2
# three    3
# dtype: int64

# %%
y = pd.Series(['foo', 'bar', 'baz'], index=[1,2,3])
y
# Out:
# 1    foo
# 2    bar
# 3    baz
# dtype: object

# %%
x.map(y)
# Out:
# one      foo
# two      bar
# three    baz
# dtype: object

# %% [markdown]
# 10. Plot

# %%
df.plot.bar()

# %%
df1 = df['Survived'].value_counts()

df1.plot.bar()

# %%
df1.plot.pie(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002ACB247EAC8>], dtype=object)

# %% [markdown]
# 11. Visualization
#     ---I hope you learn it from matplotlib library in first session

# %% [markdown]
# ---------------good luck  ----https://github.com/Kiran-Maharjan/pandas--grand-workshop-AiDevNepal
